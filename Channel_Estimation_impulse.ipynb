# %%
import numpy as np
import matplotlib.pyplot as plt
import pyaudio
import wave
from pydub import AudioSegment
import scipy
from scipy.io import wavfile #audio i/o
from IPython.display import Audio #listening to audio
import thinkdsp
import thinkstats2
# %matplotlib inline

# %% [markdown]
# Goal: Generate an impulse signal use the impluse signal to measure the channel impulse response directly

# %%
recv = thinkdsp.read_wave("impulse.wav")
recv.plot()
recv.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
response = recv.segment(start = 7+6804/44100, duration = 0.005)
response.plot()
transfer = response.make_spectrum()
plt.figure()
transfer.plot()

# %%
music = thinkdsp.read_wave('music.wav').segment(start = 1, duration = 1)
music.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
music.plot()
output = (music.make_spectrum() * transfer).make_wave()
plt.figure()
output.plot()
output.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
